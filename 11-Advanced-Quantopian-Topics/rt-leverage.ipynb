# %%
# this is the code from the full backtest the second variable in the URL
bt = get_backtest('5efa337efe228b49714387f0')
# Out:
# 100% Time:  0:00:02|##########################################################|

# %%
bt.benchmark_security
# Out:
# 8554

# %%
bt.algo_id
# Out:
# '5efa337efe228b49714387f0'

# %%
bt.recorded_vars
# Out:
#                            Exposure  Leverage  amzn_close  ibm_close
# 2017-01-04 00:00:00+00:00 -0.005567  1.007766     756.720    169.320
# 2017-01-05 00:00:00+00:00  0.012734  0.999959     780.910    168.740
# 2017-01-06 00:00:00+00:00  0.006014  1.007951     796.881    169.640
# 2017-01-09 00:00:00+00:00  0.004993  0.990320     797.170    167.750
# 2017-01-10 00:00:00+00:00  0.006452  0.986240     795.960    165.540
# 2017-01-11 00:00:00+00:00 -0.000931  1.008425     798.239    167.680
# 2017-01-12 00:00:00+00:00  0.006920  1.000907     813.700    167.710
# 2017-01-13 00:00:00+00:00  0.003203  0.996061     816.860    167.290
# 2017-01-17 00:00:00+00:00 -0.006858  1.009366     808.910    167.790
# 2017-01-18 00:00:00+00:00  0.002233  0.996318     807.400    166.780
# 2017-01-19 00:00:00+00:00 -0.001015  0.999703     809.270    166.750
# 2017-01-20 00:00:00+00:00 -0.015085  1.021903     807.630    170.120
# 2017-01-23 00:00:00+00:00  0.005799  1.002897     818.050    171.130
# ...

# %%
# this is using the 0.5 / -0.5 AMZN / IBM distribution which results in tame leverage
bt.recorded_vars['Leverage'].plot()

# %%
bt2 = get_backtest('5efa3620a72611496f7dde14')
# Out:
# 100% Time:  0:00:00|##########################################################|

# %%
# this shows a much higher leverage on the portfolio
bt2.recorded_vars['Leverage'].plot()
