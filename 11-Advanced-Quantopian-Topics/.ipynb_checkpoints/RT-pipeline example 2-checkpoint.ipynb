# %% [markdown]
# ## Pipeline Example

# %%
from quantopian.pipeline import Pipeline
from quantopian.research import run_pipeline
from quantopian.pipeline.data.builtin import USEquityPricing

# %%
# this imports the stocks filtered for top ranking in liquidity
# prevents orders from being filled on backtesting and uniformity of testing
from quantopian.pipeline.filters import Q1500US

# %%
# set these 1500 liquid stocks as our universe to work from
universe = Q1500US()

# %%
# bring in the morningstar dataset
from quantopian.pipeline.data import morningstar

# %%
# pull in morningstar sector information as a classifier
sector = morningstar.asset_classification.morningstar_sector_code.latest

# %%
# this does the same job as the previous step but a little less granular in ability to select
from quantopian.pipeline.classifiers.morningstar import Sector
morningstar_sector = Sector()

# %%
# use the classifier as a filter
energy_sector = sector.eq(309)

# %%
from quantopian.pipeline.factors import SimpleMovingAverage, AverageDollarVolume

# %%
dollar_volume = AverageDollarVolume(window_length=30)

# %%
# grab the top 10% traded in terms of dollar volume
high_dollar_volume = dollar_volume.percentile_between(90,100)

# %%
# use the previous variable as a mask in making a new one
top_open_prices = USEquityPricing.open.latest.top(50, mask=high_dollar_volume)

# %%
# can use successive variables as masks such as this
high_close_price = USEquityPricing.close.latest.percentile_between(90,100, mask=top_open_prices)

# %%
def make_pipeline():
    
    # Get the universe of 1500 most liquid stocks Q1500US
    base_universe = Q1500US()
    
    # Get the energy sector stocks from it
    energy_sector = sector.eq(309)
    
    # make mask of 1500 US & energy stocks
    base_energy = base_universe & energy_sector
    
    # get Average Dollar Volume info over past 30 days
    dollar_volume = AverageDollarVolume(window_length=30)
    
    # get top 5% of average dollar volume
    high_dollar_volume = dollar_volume.percentile_between(95,100)
    
    # Combine the filters
    top_five_base_energy = base_energy & high_dollar_volume
    
    # get 10 day mean close
    mean_10 = SimpleMovingAverage(inputs=[USEquityPricing.close], window_length=10, 
                                  mask=top_five_base_energy)
    
    # get 30 day mean close
    mean_30 = SimpleMovingAverage(inputs=[USEquityPricing.close], window_length=30,
                                  mask=top_five_base_energy)
    
    # percent difference between 10 & 30 day close
    percent_diff = ((mean_10 - mean_30) / mean_30) * 100
    
    # make list of shorts
    shorts = percent_diff < 0
    
    # make list of longs
    longs = percent_diff > 0
    
    # make a final filter for shorts or longs
    securities_to_trade = (shorts | longs)
    
    # return pipeline
    return Pipeline(columns={'shorts':shorts, 
                             'longs':longs,
                             'perc_diff':percent_diff}, screen=securities_to_trade)

# %%
result = run_pipeline(make_pipeline(), '2015-05-05', '2015-05-06')
result
# Out:
# <b>Pipeline Execution Time:</b> 18.77 Seconds
#                                                longs  perc_diff shorts
# 2015-05-05 00:00:00+00:00 Equity(216 [HES])     True   3.652774  False
#                           Equity(448 [APA])     True   3.592648  False
#                           Equity(455 [APC])     True   4.915320  False
#                           Equity(858 [BHI])     True   3.380742  False
#                           Equity(1746 [COG])    True   5.807811  False
#                           Equity(2368 [DVN])    True   4.626405  False
#                           Equity(2564 [EOG])    True   3.210162  False
#                           Equity(2621 [VAL])    True   6.019737  False
#                           Equity(3443 [HAL])    True   4.925735  False
#                           Equity(3647 [HP])     True   4.099079  False
#                           Equity(5035 [MRO])    True   6.159811  False
#                           Equity(5213 [NBL])    True   1.044319  False
#                           Equity(5214 [NBR])    True   6.413320  False
#                           Equity(5249 [NE])     True   3.755930  False
#                           Equity(5729 [OXY])    True   2.977590  False
#                           Equity(6928 [SLB])    True   4.655503  False
#                           Equity(7244 [SWN])    True   7.078785  False
#                           Equity(7612 [ANDV])   True   0.599650  False
#                           Equity(7990 [VLO])   False  -1.714509   True
#                           Equity(8214 [WMB])    True   1.887571  False
#                           Equity(8347 [XOM])    True   1.734263  False
#                           Equity(8461 [CHK])    True   1.426484  False
#                           Equity(9038 [RIG])    True   4.817961  False
#                           Equity(13176 [CAM])   True   8.211039  False
#                           Equity(17436 [PXD])   True   1.024757  False
#                           Equity(19249 [RRC])   True   8.706193  False
#                           Equity(19336 [WFT])   True   4.914117  False
#                           Equity(22784 [FTI])   True   5.452895  False
#                           Equity(23112 [CVX])   True   1.897175  False
#                           Equity(23998 [COP])   True   2.390157  False
# ...                                              ...        ...    ...
# 2015-05-06 00:00:00+00:00 Equity(3647 [HP])     True   4.425890  False
#                           Equity(5035 [MRO])    True   5.610144  False
#                           Equity(5213 [NBL])    True   0.551156  False
#                           Equity(5214 [NBR])    True   7.022000  False
#                           Equity(5249 [NE])     True   4.217467  False
#                           Equity(5729 [OXY])    True   2.615267  False
#                           Equity(6928 [SLB])    True   4.348109  False
#                           Equity(7244 [SWN])    True   7.135257  False
#                           Equity(7612 [ANDV])   True   1.101426  False
#                           Equity(7990 [VLO])   False  -1.522931   True
#                           Equity(8214 [WMB])    True   1.451714  False
#                           Equity(8347 [XOM])    True   1.807026  False
#                           Equity(8461 [CHK])    True   1.886690  False
#                           Equity(9038 [RIG])    True   5.223957  False
#                           Equity(13176 [CAM])   True   8.614055  False
#                           Equity(17436 [PXD])   True   0.334860  False
#                           Equity(19249 [RRC])   True   8.319245  False
#                           Equity(19336 [WFT])   True   5.119354  False
#                           Equity(22784 [FTI])   True   6.292438  False
#                           Equity(23112 [CVX])   True   1.669151  False
#                           Equity(23998 [COP])   True   2.058818  False
#                           Equity(24125 [XEC])   True   0.876334  False
#                           Equity(24809 [NOV])   True   2.536166  False
#                           Equity(25707 [WLL])   True   5.509818  False
#                           Equity(33856 [CLR])   True   5.368222  False
#                           Equity(34440 [CXO])   True   3.594000  False
#                           Equity(39797 [OAS])   True   3.146251  False
#                           Equity(40852 [KMI])   True   2.108406  False
#                           Equity(41636 [MPC])   True   1.396023  False
#                           Equity(42788 [PSX])   True   2.125137  False
#
# [77 rows x 3 columns]
